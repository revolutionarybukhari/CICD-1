# %%
import pandas as pd

# %%
df=pd.read_csv("Diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df=df.dropna()
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
df = df.rename(columns={'DiabetesPedigreeFunction': 'DPF'})
df = df.rename(columns={'Outcome': 'prediction'})

# %%
X = df.drop("prediction", axis=1)
y = df["prediction"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

model_decision_tree=DecisionTreeClassifier(random_state=42)
model_decision_tree.fit(X_train, y_train)
y_pred = model_decision_tree.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Decision tree results ")
print("Accuracy = ", accuracy)
print("Precision = ", precision)
print("Recall = ", recall)
print("F1-score = ", f1)

model_random_forest=RandomForestClassifier(random_state=42)
model_random_forest.fit(X_train, y_train)
y_pred = model_random_forest.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Random forest results ")
print("Accuracy = ", accuracy)
print("Precision = ", precision)
print("Recall = ", recall)
print("F1-score = ", f1)

model_adaboost=AdaBoostClassifier(random_state=42)
model_adaboost.fit(X_train, y_train)
y_pred = model_adaboost.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("AdaBoost results ")
print("Accuracy = ", accuracy)
print("Precision = ", precision)
print("Recall = ", recall)
print("F1-score = ", f1)
# Out:
# Decision tree results
# Accuracy =  0.7922077922077922
# Precision =  0.6896551724137931
# Recall =  0.7407407407407407
# F1-score =  0.7142857142857143
# Random forest results
# Accuracy =  0.6883116883116883
# Precision =  0.5517241379310345
# Recall =  0.5925925925925926
# F1-score =  0.5714285714285714
# AdaBoost results
# Accuracy =  0.7532467532467533
# Precision =  0.6428571428571429
# Recall =  0.6666666666666666
# F1-score =  0.6545454545454545

# %%
# dt_params = {
#     "max_depth": [3, 5, 7],
#     "min_samples_split": [2, 5],
#     "min_samples_leaf": [1, 2],
# }
# model_decision_tree=DecisionTreeClassifier()
# optimized_model={}
# grid_search = GridSearchCV(model_decision_tree, dt_params , scoring="accuracy", cv=5)
# grid_search.fit(X_train, y_train)
# optimized_model["decision_tree"] = grid_search.best_estimator_


# optimized_model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

class HyperparameterTuner:
    def __init__(self, models, param_grids, X_train, y_train):
        self.models = models
        self.param_grids = param_grids
        self.X_train = X_train
        self.y_train = y_train
        self.optimized_models = {}

    def optimize_models(self):
        for name, model in self.models.items():
            grid_search = GridSearchCV(model, self.param_grids[name], scoring="accuracy", cv=5)
            grid_search.fit(self.X_train, self.y_train)
            self.optimized_models[name] = grid_search.best_estimator_

            print(f"{name} best parameters:")
            print(grid_search.best_params_, "\n")

    def print_results(self, X_test, y_test):
        for name, model in self.optimized_models.items():
            y_pred = model.predict(X_test)
            accuracy = accuracy_score(y_test, y_pred)
            precision = precision_score(y_test, y_pred)
            recall = recall_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred)

            print(f"{name} results")
            print("Accuracy =", accuracy)
            print("Precision =", precision)
            print("Recall =", recall)
            print("F1-score =", f1)
            print()

# Define the models and hyperparameter grids
models = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "Adaboost": AdaBoostClassifier(),
}

dt_params = {
    "max_depth": [3, 5, 7],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
}

rf_params = {
    "n_estimators": [50, 100],
    "max_depth": [3, 5],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
}

ada_params = {
    "n_estimators": [50, 100],
    "learning_rate": [0.1, 1.0],
}

param_grids = {
    "Decision Tree": dt_params,
    "Random Forest": rf_params,
    "Adaboost": ada_params,
}

# Instantiate the tuner and optimize the models
tuner = HyperparameterTuner(models, param_grids, X_train, y_train)
tuner.optimize_models()

# Print the results on the test data
tuner.print_results(X_test, y_test)
# Out:
# Decision Tree best parameters:
# {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2}
#
# Random Forest best parameters:
# {'max_depth': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 50}
#
# Adaboost best parameters:
# {'learning_rate': 0.1, 'n_estimators': 100}
#
# Decision Tree results
# Accuracy = 0.7662337662337663
# Precision = 0.6666666666666666
# Recall = 0.6666666666666666
# F1-score = 0.6666666666666666
#
# Random Forest results
# Accuracy = 0.7142857142857143
# Precision = 0.5862068965517241
# Recall = 0.6296296296296297
# F1-score = 0.6071428571428571
#
# Adaboost results
# Accuracy = 0.7272727272727273
# Precision = 0.6071428571428571
# Recall = 0.6296296296296297
# F1-score = 0.6181818181818182

# %%
model_random_forest = RandomForestClassifier(random_state=42)
model_random_forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import joblib

# Save the model to a file
joblib.dump(model_random_forest, 'model_random_forest.pkl')
# Out:
# ['model_random_forest.pkl']
